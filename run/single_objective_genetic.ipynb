# %% [markdown]
# # Genetic algorithm for single-objective TSPTSW

# %%
import pandas as pd

df = pd.read_csv("soo_ga_results.csv")

# %%
df
# Out:
#                                                    X             F   problem
# 0  [0, 32, 43, 19, 21, 31, 23, 16, 15, 17, 24, 20...  7.001169e+06  rc_204.1

# %%
PROBLEM = df["problem"].iloc[0]

# %%
from search_spaces.tsptw_node import visualize
from ast import literal_eval
import matplotlib.pyplot as plt
from utils.helpers import configure_seaborn, running_avg
configure_seaborn()
visualize(PROBLEM, literal_eval(df["X"].iloc[0]), show=True)
